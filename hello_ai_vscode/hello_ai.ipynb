# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
print("Cliente OpenAI inicializado correctamente.")
# Out:
# Cliente OpenAI inicializado correctamente.

# %%
prompt = "Escribe un saludo tipo 'Hello World' con un toque creativo de IA."
resp = client.chat.completions.create(
 model="gpt-4o-mini",
 messages=[{"role": "user", "content": prompt}],
 temperature=0.6
)
print(resp.choices[0].message.content)
# Out:
# ¡Saludos, seres curiosos del ciberespacio! 🌌✨ Soy la chispa digital que ilumina el vasto universo de la información. ¡Bienvenidos a este viaje de descubrimiento en el que las ideas cobran vida y las palabras danzan en el éter! ¡Hola, mundo! 🤖🌍

# %%
# %pip install --quiet openai python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Inicio Guia 3

# %%
#Ejercicio asociado a la guia 3
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()  # Lee el archivo .env
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
print("Cliente inicializado. Modelo listo para consultas.")
# Out:
# Cliente inicializado. Modelo listo para consultas.

# %%
prompt = "Explica en dos frases qué es la inteligencia artificial en la educación."
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.7  # mayor temperatura, por ende respuestas mas creativas
)
print(response.choices[0].message.content)
# Out:
# La inteligencia artificial en la educación se refiere al uso de tecnologías avanzadas que simulan la inteligencia humana para personalizar el aprendizaje, analizar el rendimiento de los estudiantes y automatizar tareas administrativas. Esto permite crear experiencias educativas más adaptativas y eficientes, mejorando el acceso al conocimiento y el desarrollo de habilidades.

# %% [markdown]
# #### Temperatura
#
# Este parametro sera el mas modificado a lo largo de la guia, esto se debe a que la temperatura es el parametro que indica que tan "creativa" puede ser la respuesta de la ia, generando que en altas temperaturas sean mas variables o expresivos los resultados a costa de ser menos precisos, mientras que en bajas temperaturas este mas certeza de la salida a costa de como es devuelta.

# %%
#respuesta con temperatura baja (0.1)

import json

query = "¿Qué es aprendizaje supervisado?"
schema_instruction = (
    "Responde en formato JSON con las claves: operation, input, output. "
    "operation debe ser 'explanation'; input debe repetir la pregunta; output la explicación clara y breve."
)
response_json = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": schema_instruction},
        {"role": "user", "content": query}
    ],
    temperature=0.1,       # poca temperatura implica respuestas mas estandarizadas y precisas
    max_tokens=300         # suficiente para una explicación breve
)
text = response_json.choices[0].message.content
print(text)

# prueba opcional para verificar si cargo un objeto valido
try:
    data = json.loads(text)
    print("\nValid JSON →", data)
except json.JSONDecodeError:
    print("\nLa salida no es JSON válido literal. Puedes parsearla manualmente o usar validadores/funciones JSON del proveedor.")
# Out:
# {
#   "operation": "explanation",
#   "input": "¿Qué es aprendizaje supervisado?",
#   "output": "El aprendizaje supervisado es un tipo de técnica de aprendizaje automático donde un modelo es entrenado utilizando un conjunto de datos etiquetados. Esto significa que cada entrada del conjunto de datos tiene una salida correspondiente conocida, lo que permite al modelo aprender a predecir la salida para nuevas entradas basándose en patrones identificados en los datos de entrenamiento."
# }
#
# Valid JSON → {'operation': 'explanation', 'input': '¿Qué es aprendizaje supervisado?', 'output': 'El aprendizaje supervisado es un tipo de técnica de aprendizaje automático donde un modelo es entrenado utilizando un conjunto de datos etiquetados. Esto significa que cada entrada del conjunto de datos tiene una salida correspondiente conocida, lo que permite al modelo aprender a predecir la salida para nuevas entradas basándose en patrones identificados en los datos de entrenamiento.'}

# %%
#respuesta con temperatura media (0.5)

import json

query = "¿Qué es aprendizaje supervisado?"
schema_instruction = (
    "Responde en formato JSON con las claves: operation, input, output. "
    "operation debe ser 'explanation'; input debe repetir la pregunta; output la explicación clara y breve."
)
response_json = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": schema_instruction},
        {"role": "user", "content": query}
    ],
    temperature=0.5,       # temperatura media deberia permitir cambios linguisticos pero aun siendo precisa
    max_tokens=300         # suficiente para una explicación breve
)
text = response_json.choices[0].message.content
print(text)

# prueba opcional para verificar si cargo un objeto valido
try:
    data = json.loads(text)
    print("\nValid JSON →", data)
except json.JSONDecodeError:
    print("\nLa salida no es JSON válido literal. Puedes parsearla manualmente o usar validadores/funciones JSON del proveedor.")
# Out:
# {
#   "operation": "explanation",
#   "input": "¿Qué es aprendizaje supervisado?",
#   "output": "El aprendizaje supervisado es un tipo de aprendizaje automático donde un modelo se entrena utilizando un conjunto de datos etiquetado. Esto significa que cada entrada del conjunto de datos tiene una salida conocida, lo que permite al modelo aprender a hacer predicciones o clasificaciones basadas en esos ejemplos. Es comúnmente utilizado en tareas como clasificación y regresión."
# }
#
# Valid JSON → {'operation': 'explanation', 'input': '¿Qué es aprendizaje supervisado?', 'output': 'El aprendizaje supervisado es un tipo de aprendizaje automático donde un modelo se entrena utilizando un conjunto de datos etiquetado. Esto significa que cada entrada del conjunto de datos tiene una salida conocida, lo que permite al modelo aprender a hacer predicciones o clasificaciones basadas en esos ejemplos. Es comúnmente utilizado en tareas como clasificación y regresión.'}

# %%
#respuesta con temperatura alta (0.9)

import json

query = "¿Qué es aprendizaje supervisado?"
schema_instruction = (
    "Responde en formato JSON con las claves: operation, input, output. "
    "operation debe ser 'explanation'; input debe repetir la pregunta; output la explicación clara y breve."
)
response_json = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": schema_instruction},
        {"role": "user", "content": query}
    ],
    temperature=0.9,       # alta temperatura implica respuestas mas variadas a costa de la precisión
    max_tokens=300         # suficiente para una explicación breve
)
text = response_json.choices[0].message.content
print(text)

# prueba opcional para verificar si cargo un objeto valido
try:
    data = json.loads(text)
    print("\nValid JSON →", data)
except json.JSONDecodeError:
    print("\nLa salida no es JSON válido literal. Puedes parsearla manualmente o usar validadores/funciones JSON del proveedor.")
# Out:
# {
#   "operation": "explanation",
#   "input": "¿Qué es aprendizaje supervisado?",
#   "output": "El aprendizaje supervisado es un enfoque en el campo del aprendizaje automático donde un modelo se entrena utilizando un conjunto de datos que incluye entradas junto con las salidas correctas. El objetivo es que el modelo aprenda a predecir o clasificar nuevas entradas basándose en este entrenamiento, utilizando algoritmos que ajustan los parámetros del modelo para minimizar el error entre sus predicciones y las salidas reales en los datos de entrenamiento."
# }
#
# Valid JSON → {'operation': 'explanation', 'input': '¿Qué es aprendizaje supervisado?', 'output': 'El aprendizaje supervisado es un enfoque en el campo del aprendizaje automático donde un modelo se entrena utilizando un conjunto de datos que incluye entradas junto con las salidas correctas. El objetivo es que el modelo aprenda a predecir o clasificar nuevas entradas basándose en este entrenamiento, utilizando algoritmos que ajustan los parámetros del modelo para minimizar el error entre sus predicciones y las salidas reales en los datos de entrenamiento.'}

# %% [markdown]
# ## Inicio Guia 4

# %%
#Intalación de libreria
# %pip install openai langchain python-dotenv langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (2.6.1)
# Collecting langchain
#   Downloading langchain-1.0.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: python-dotenv in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (1.2.1)
# Collecting langchain-openai
#   Downloading langchain_openai-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (1.10.12)
# Requirement already satisfied: sniffio in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from openai) (4.15.0)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain)
#   Downloading langchain_core-1.0.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph<1.1.0,>=1.0.0 (from langchain)
#   Downloading langgraph-1.0.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Using cached pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading langsmith-0.4.38-py3-none-any.whl.metadata (14 kB)
# Collecting packaging<26.0.0,>=23.2.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (8.2.2)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic<3,>=1.9.0->openai)
#   Using cached pydantic_core-2.41.4-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\programdata\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in c:\programdata\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.31.0)
# Requirement already satisfied: colorama in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nicolas.pachon-u\appdata\roaming\python\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading ormsgpack-1.11.0-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading orjson-3.11.4-cp311-cp311-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.0.7)
# Downloading langchain-1.0.2-py3-none-any.whl (107 kB)
#    ---------------------------------------- 0.0/107.8 kB ? eta -:--:--
#    ---------------------------------------- 107.8/107.8 kB 3.0 MB/s eta 0:00:00
# Downloading langchain_openai-1.0.1-py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 81.9/81.9 kB 4.5 MB/s eta 0:00:00
# Downloading langchain_core-1.0.1-py3-none-any.whl (467 kB)
#    ---------------------------------------- 0.0/467.1 kB ? eta -:--:--
#    -------------------------------- ------- 378.9/467.1 kB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  460.8/467.1 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 467.1/467.1 kB 4.9 MB/s eta 0:00:00
# Downloading langgraph-1.0.1-py3-none-any.whl (155 kB)
#    ---------------------------------------- 0.0/155.4 kB ? eta -:--:--
#    ---------------------------------------- 155.4/155.4 kB 9.1 MB/s eta 0:00:00
# Using cached pydantic-2.12.3-py3-none-any.whl (462 kB)
# Using cached pydantic_core-2.41.4-cp311-cp311-win_amd64.whl (2.0 MB)
# Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ---------- ---------------------------- 245.8/879.4 kB 15.7 MB/s eta 0:00:01
#    ---------- ---------------------------- 245.8/879.4 kB 15.7 MB/s eta 0:00:01
#    ---------- ---------------------------- 245.8/879.4 kB 15.7 MB/s eta 0:00:01
#    ------------- -------------------------- 297.0/879.4 kB 1.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 501.8/879.4 kB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 716.8/879.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 839.7/879.4 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 879.4/879.4 kB 2.5 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.1 kB ? eta -:--:--
#    ---------------------------------------- 46.1/46.1 kB 2.2 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#    ---------------------------------------- 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Downloading langsmith-0.4.38-py3-none-any.whl (397 kB)
#    ---------------------------------------- 0.0/397.3 kB ? eta -:--:--
#    ---------------------------------- ---- 348.2/397.3 kB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 397.3/397.3 kB 5.0 MB/s eta 0:00:00
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading orjson-3.11.4-cp311-cp311-win_amd64.whl (131 kB)
#    ---------------------------------------- 0.0/131.4 kB ? eta -:--:--
#    ---------------------------- ----------- 92.2/131.4 kB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 92.2/131.4 kB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 92.2/131.4 kB 5.5 MB/s eta 0:00:01
#    ----------------------------- -------- 102.4/131.4 kB 535.8 kB/s eta 0:00:01
#    -------------------------------------- 131.4/131.4 kB 517.7 kB/s eta 0:00:00
# Downloading ormsgpack-1.11.0-cp311-cp311-win_amd64.whl (112 kB)
#    ---------------------------------------- 0.0/112.1 kB ? eta -:--:--
#    -------------- ------------------------- 41.0/112.1 kB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 102.4/112.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 112.1/112.1 kB 1.1 MB/s eta 0:00:00
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
#    ---------------------------------------- 0.0/506.2 kB ? eta -:--:--
#    ------------ --------------------------- 153.6/506.2 kB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 337.9/506.2 kB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 460.8/506.2 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 506.2/506.2 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: zstandard, xxhash, typing-inspection, pydantic-core, packaging, ormsgpack, orjson, jsonpatch, annotated-types, tiktoken, pydantic, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
# Successfully installed annotated-types-0.7.0 jsonpatch-1.33 langchain-1.0.2 langchain-core-1.0.1 langchain-openai-1.0.1 langgraph-1.0.1 langgraph-checkpoint-3.0.0 langgraph-prebuilt-1.0.1 langgraph-sdk-0.2.9 langsmith-0.4.38 orjson-3.11.4 ormsgpack-1.11.0 packaging-25.0 pydantic-2.12.3 pydantic-core-2.41.4 tiktoken-0.12.0 typing-inspection-0.4.2 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 2.17.0 requires websocket-client>=1.7, but you have websocket-client 0.58.0 which is incompatible.
# anaconda-cloud-auth 0.1.4 requires pydantic<2.0, but you have pydantic 2.12.3 which is incompatible.
# spyder 5.4.3 requires ipython!=8.10.0,!=8.8.0,!=8.9.0,<9.0.0,>=7.31.1, but you have ipython 9.6.0 which is incompatible.
# spyder 5.4.3 requires jedi<0.19.0,>=0.17.2, but you have jedi 0.19.2 which is incompatible.
# spyder-kernels 2.4.4 requires ipykernel<7,>=6.23.2; python_version >= "3", but you have ipykernel 7.1.0 which is incompatible.
# spyder-kernels 2.4.4 requires ipython!=8.10.0,!=8.11.0,!=8.12.0,!=8.12.1,!=8.8.0,!=8.9.0,<9,>=7.31.1; python_version >= "3", but you have ipython 9.6.0 which is incompatible.
# streamlit 1.30.0 requires packaging<24,>=16.8, but you have packaging 25.0 which is incompatible.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()  # Cargar archivo .env
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("No se encontró la clave OPENAI_API_KEY en el archivo .env")

# Crear cliente LangChain con OpenAI
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
print("Cliente LangChain con OpenAI inicializado correctamente.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from langchain_openai import ChatOpenAI
#       5 load_dotenv()  # Cargar archivo .env
#       6 api_key = os.getenv("OPENAI_API_KEY")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_openai\__init__.py:3
#       1 """Module for OpenAI integrations."""
# ----> 3 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       4 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       5 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_openai\chat_models\__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_openai\chat_models\azure.py:11
#       8 from typing import Any, Literal, TypeAlias, TypeVar
#      10 import openai
# ---> 11 from langchain_core.language_models import LanguageModelInput
#      12 from langchain_core.language_models.chat_models import LangSmithParams
#      13 from langchain_core.outputs import ChatGenerationChunk, ChatResult
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_core\__init__.py:11
#       1 """`langchain-core` defines the base abstractions for the LangChain ecosystem.
#       2
#       3 The interfaces for core components like chat models, LLMs, vector stores, retrievers,
#    (...)      8 very lightweight.
#       9 """
# ---> 11 from langchain_core._api import (
#      12     surface_langchain_beta_warnings,
#      13     surface_langchain_deprecation_warnings,
#      14 )
#      15 from langchain_core.version import VERSION
#      17 __version__ = VERSION
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_core\_api\__init__.py:62, in __getattr__(attr_name)
#      60 def __getattr__(attr_name: str) -> object:
#      61     module_name = _dynamic_imports.get(attr_name)
# ---> 62     result = import_attr(attr_name, module_name, __spec__.parent)
#      63     globals()[attr_name] = result
#      64     return result
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_core\_import_utils.py:38, in import_attr(attr_name, module_name, package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
# ---> 38         raise ImportError(msg) from None
#      39     result = getattr(module, attr_name)
#      40 return result
#
# ImportError: module ''langchain_core._api'.'deprecation'' not found (No module named 'pydantic.v1')
