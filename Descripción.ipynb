# %% [markdown]
# # Taller 9 AREP: Large Language Models
# **Realizado por:** Nicolás Pachón Unibio

# %% [markdown]
# ### Entorno virtual
#
# para el correcto funcionamiento del laboratorio se debe crear un entorno virtual en python, para esto se utiliza el siguiente comando dentro de la carpeta donde se desea crear el entorno virtual, mediante el CMD o consola del sistema operativo utilizado

# %%
# !python -m venv venv

# %% [markdown]
# Con esto se procede a realizar la activación del entorno virtual mediante el siguiente comando

# %%
#En windows
venv\Scripts\activate

#En macOS/Linux
source venv\bin\activate

# %% [markdown]
# ### Librerias utilizadas:
# En este caso se usaron las siguientes librerias para el funcionamiento del RAG

# %%
# %pip install openai python-dotenv
# %pip install jupyterlab
# %pip install openai
# %pip install tiktoken
# %pip install langchain
# %pip install openai
# %pip install chromadb
# %pip install langchainhub
# %pip install bs4
# %pip install pinecone-client
# %pip install langchain-pinecone
# %pip install langchain-community
# %pip install langchain-classic
# Out:
# ...
#   Using cached openai-2.8.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached jiter-0.12.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
# Using cached openai-2.8.0-py3-none-any.whl (1.0 MB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.12.0-cp312-cp312-win_amd64.whl (205 kB)
# Using cached pydantic-2.12.4-py3-none-any.whl (463 kB)
# ...

# %% [markdown]
# ### Llaves:
#
# en esta ocasión, el laboratorio hara uso de llaves de pinecone y openai, no obstante, estas no seran mostradas en el transcruso del trabajo al ser privadas, para su uso se recomienda hacer un archivo *.env* y ahi mismo digitar la siguiente información:

# %%
OPENAI_API_KEY =  <inserte su llave aqui>
PINECONE_API_KEY = <inserte su llave aqui>
PINECONE_ENV = "gcp-starter"
